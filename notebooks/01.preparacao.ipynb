# %%
import pandas as pd

# %%
raw_data = catalog.load("raw_dev")
# Out:
#                     INFO     Loading data from raw_dev (ParquetDataset)...                      ]8;id=904556;file:///home/rosana/.conda/envs/PD_env_1/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=231375;file:///home/rosana/.conda/envs/PD_env_1/lib/python3.11/site-packages/kedro/io/data_catalog.py#401\401]8;;\

# %%
raw_data.head(30)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            action_type combined_shot_type  game_event_id   game_id      lat  \
# 0            Jump Shot          Jump Shot             10  20000012  33.9723
# 1            Jump Shot          Jump Shot             12  20000012  34.0443
# 2            Jump Shot          Jump Shot             35  20000012  33.9093
# 3            Jump Shot          Jump Shot             43  20000012  33.8693
# 4    Driving Dunk Shot               Dunk            155  20000012  34.0443
# 5            Jump Shot          Jump Shot            244  20000012  34.0553
# 6           Layup Shot              Layup            251  20000012  34.0443
# 7            Jump Shot          Jump Shot            254  20000012  34.0163
# 8            Jump Shot          Jump Shot            265  20000012  33.9363
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24271 entries, 0 to 30696
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   action_type         24271 non-null  object
#  1   combined_shot_type  24271 non-null  object
#  2   game_event_id       24271 non-null  int64
#  3   game_id             24271 non-null  int64
#  4   lat                 24271 non-null  float64
#  5   loc_x               24271 non-null  int64
#  6   loc_y               24271 non-null  int64
#  7   lon                 24271 non-null  float64
#  8   minutes_remaining   24271 non-null  int64
#  9   period              24271 non-null  int64
#  10  playoffs            24271 non-null  int64
#  11  season              24271 non-null  object
#  12  seconds_remaining   24271 non-null  int64
#  13  shot_distance       24271 non-null  int64
#  14  shot_made_flag      20285 non-null  float64
# ...

# %%
# lat
# lng
# minutes remaining
# period
# playoffs
# shot_distance

raw_data_unique = raw_data.drop_duplicates()

data = raw_data_unique[[
    'lat', 'lon','minutes_remaining','period','playoffs','shot_distance', 'shot_made_flag'
]].dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20285 entries, 1 to 30696
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   lat                20285 non-null  float64
#  1   lon                20285 non-null  float64
#  2   minutes_remaining  20285 non-null  int64
#  3   period             20285 non-null  int64
#  4   playoffs           20285 non-null  int64
#  5   shot_distance      20285 non-null  int64
#  6   shot_made_flag     20285 non-null  float64
# dtypes: float64(3), int64(4)
# memory usage: 1.2 MB

# %%
data['shot_made_flag'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# shot_made_flag
# 0.0    10602
# 1.0     9683
# Name: count, dtype: int64

# %%
data
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            lat       lon  minutes_remaining  period  playoffs  shot_distance  \
# 1      34.0443 -118.4268                 10       1         0             15
# 2      33.9093 -118.3708                  7       1         0             16
# 3      33.8693 -118.1318                  6       1         0             22
# 4      34.0443 -118.2698                  6       2         0              0
# 5      34.0553 -118.4148                  9       3         0             14
# ...        ...       ...                ...     ...       ...            ...
# 30690  33.9443 -118.3828                 11       4         1             15
# 30691  34.0443 -118.2698                  7       4         1              0
# 30692  33.9963 -118.2688                  6       4         1              4
# ...

# %%
data['playoffs'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# playoffs
# 0    17268
# 1     3017
# Name: count, dtype: int64

# %%
data['period'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# period
# 1    5584
# 3    5563
# 2    4482
# 4    4405
# 5     224
# 6      22
# 7       5
# Name: count, dtype: int64

# %%
data = raw_data_unique[[
    'lat', 'lon','minutes_remaining','period','playoffs','shot_distance', 'shot_made_flag'
]].dropna().assign(playoffs = lambda x: x['playoffs'].astype(bool)).assign(shot_made_flag = lambda x: x['shot_made_flag'].astype(bool))

data
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            lat       lon  minutes_remaining  period  playoffs  shot_distance  \
# 1      34.0443 -118.4268                 10       1     False             15
# 2      33.9093 -118.3708                  7       1     False             16
# 3      33.8693 -118.1318                  6       1     False             22
# 4      34.0443 -118.2698                  6       2     False              0
# 5      34.0553 -118.4148                  9       3     False             14
# ...        ...       ...                ...     ...       ...            ...
# 30690  33.9443 -118.3828                 11       4      True             15
# 30691  34.0443 -118.2698                  7       4      True              0
# 30692  33.9963 -118.2688                  6       4      True              4
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# verificando os dados de lat e lon

plt.figure(figsize=(8, 5))
sns.histplot(data["lon"], bins=30, kde=True) 
plt.xlabel("Shot lon")
plt.ylabel("Frequency")
plt.title("Distribution of lon")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x500 with 1 Axes>

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data["lat"], bins=30, kde=True) 
plt.xlabel("Shot lat")
plt.ylabel("Frequency")
plt.title("Distribution of lat")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x500 with 1 Axes>

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data["shot_distance"], bins=30, kde=True)  
plt.xlabel("Shot shot_distance")
plt.ylabel("Frequency")
plt.title("Distribution of shot_distance")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x500 with 1 Axes>
